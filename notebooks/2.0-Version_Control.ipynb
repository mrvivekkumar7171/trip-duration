# %% [markdown]
# ## 1. Version Control using Git and GitHub

# %% [markdown]
# Version control is a fundamental and indispensable system that underpins the development and maintenance of software projects. It provides a structured and efficient way to track and manage changes made to your codebase over time. Whether you are working solo or collaborating with a team, version control offers a range of benefits that enhance the quality and reliability of your software.
#
# ###  ** Common Git status indicator icons in VSCode:**
#
# | Icon | Color  | Meaning                                |
# |------|--------|----------------------------------------|
# | `U`  | Red    | Untracked — new file not staged yet    |
# | `A`  | Blue   | Added — staged, waiting to commit      |
# | `M`  | Orange | Modified — file changed, not staged    |
# | `D`  | Red    | Deleted — file deleted, not staged     |
# | `R`  |        | Renamed — file renamed                 |
# | `C`  |        | Copied — file copied                   |
# | `!`  | Yellow | Conflict — merge conflict              |

# %% [markdown]
# #### Key Aspects of Version Control

# %% [markdown]
# Version control systems (VCS) encompass several key aspects:
#
# 1. **Change Tracking:** Version control allows you to monitor every alteration made to your codebase, no matter how small. Each change, or "commit," is documented and timestamped, creating a detailed history of your project's evolution.
#
# 2. **Collaboration:** VCS enables seamless collaboration among developers. Multiple team members can work on the same project concurrently, with the ability to merge their changes systematically.
#
# 3. **Reversion:** Inevitably, mistakes or unforeseen issues can arise during development. Version control makes it possible to revert to a previous state of the project, helping you recover from errors or bugs.
#
# 4. **Branching:** VCS allows the creation of branches, which are independent lines of development. This is particularly useful for parallel work on different features or bug fixes without interfering with the main project.
#
# 5. **Documentation:** Detailed commit messages and comments accompany each change, providing context and insight into the reasons behind the modifications. This documentation is invaluable for project maintenance and knowledge sharing.

# %% [markdown]
# #### Types of Version Control Systems

# %% [markdown]
# There are two primary categories of version control systems:
#
# 1. **Centralized Version Control Systems (CVCS):** In a CVCS, there is a central repository that stores the entire history and current state of the project. Developers can check out files, make changes, and commit them back to the central repository.
#
# 2. **Distributed Version Control Systems (DVCS):** DVCS systems like Git provide each developer with a complete copy of the project, including its entire history. This decentralization offers more flexibility, independence, and a distributed workflow. Example: Github etc.

# %% [markdown]
# #### Example: Using Git for Version Control

# %% [markdown]
# Git is one of the most popular distributed version control systems. Here is a basic workflow example:
#
# 1. **Initialization:** Start a Git repository by running `git init` in your project directory.
#
# 2. **Adding Files:** Stage your files with `git add` to include them in the next commit.
#
# 3. **Committing:** Create a snapshot of your project with `git commit -m "Your commit message"`.
#
# 4. **Branching:** Create a new branch with `git branch`, switch to it with `git checkout`, and merge it with the main branch when your feature is complete.
#
# 5. **Collaboration:** Push your changes to a remote repository, and others can clone and collaborate on your project.
#
# Version control systems like Git play a pivotal role in software development, helping teams collaborate efficiently, track changes, and manage the software's evolution over time.

# %% [markdown]
# ### GitHub

# %% [markdown]
# #### 1. What is GitHub?

# %% [markdown]
# GitHub is a web-based platform for version control and collaboration. It allows developers to work on projects, track changes, and collaborate with others efficiently. GitHub uses Git, a distributed version control system, as its underlying technology.

# %% [markdown]
# #### 2. Setting Up GitHub

# %% [markdown]
# Before you get started with GitHub, you need to create an account. Visit [GitHub](https://github.com/) and sign up for a free account if you don't already have one.

# %% [markdown]
# #### 3. Creating a Repository

# %% [markdown]
# A repository, or "repo" for short, is where your project and its files are stored (same like a folder on your computer). To create a new repository:
#
# - Log in to GitHub.
# - Click the **+** sign in the top right corner and select **New repository**.
# - Enter a name for your repository.
# - Choose between a public or private repository. Public repositories are visible to everyone, while private repositories are only visible to you and collaborators.
# - Optionally, select the option to initialize the repository with a README file, which can serve as documentation for your project.
# - Click **Create repository**.

# %% [markdown]
# #### 4. Cloning a Repository

# %% [markdown]
# Cloning a repository means creating a local copy on your computer to work with. To clone a repository:
#
# - Go to the repository you want to clone on GitHub.
# - Click the **Code** button, and copy the URL.
# - Open your terminal or command prompt.
# - Navigate to the directory where you want to clone the repository.
# - Run the following command to clone the repository:
# ```
# git clone <repository_URL>
# ```

# %% [markdown]
# #### 5. Making Changes

# %% [markdown]
# Once you have the repository on your computer, you can make changes to the files inside. Use your preferred code editor to make modifications.
#
# **NOTE** - I suggest using VS Code for your projects. I find it fast, reliable and extendable.

# %% [markdown]
# #### 6. Committing Changes

# %% [markdown]
# After making changes, you need to commit them to your local repository. This is like taking a snapshot of your changes. Use the following commands:
#
# - To stage your changes:
# ```
# git add .
# ```
# - To commit your changes:
# ```
# git commit -m "Your commit message"
# ```

# %% [markdown]
# #### 7. Pushing Changes

# %% [markdown]
# - To send your local commits to the GitHub repository, use the following command:
# ```
# git push origin <branch_name>
# ```

# %% [markdown]
# #### 8. Branching

# %% [markdown]
# Branches allow you to work on different features or bug fixes without affecting the main project. To create a new branch:
#
# - Create a branch:
# ```
# git branch <new_branch_name>
# ```
# - Switch to the new branch:
# ```
# git checkout <new_branch_name>
# ```

# %% [markdown]
# #### 9. Pull Requests

# %% [markdown]
# When you're ready to merge your changes into the main project, you create a pull request (PR). To create a PR:
#
# - Go to the repository on GitHub.
# - Click the **Pull requests** tab.
# - Click the **New pull request** button.
# - Select the branches you want to compare.
# - Write a description and click **Create pull request**.
#
# To **delete** the **local** branch after the **successful merging** of the local branch to the **main branch**:
#
#     . git branch -d TheSoftMax_test
#
# To delete **without merge** to the main branch
#
#     . git branch -D TheSoftMax_test
#
# To delete the **remote branch on GitHub** when the local is already deleted:
#
#     . git push origin --delete TheSoftMax_test
#
# To check your branches on **local and remote**:
#
#     . git branch -a
#
# Delete the **remote** branch:
#
#     . git push origin --delete TheSoftMax_test
#
# To **fetch the current status** of all branches:
#
#     . git fetch -p

# %% [markdown]
# #### 10. Collaborating with Others

# %% [markdown]
# GitHub is excellent for collaborating with others. You can invite collaborators to your repository, and they can work on the same project. It's important to follow the same procedures for making changes, committing, pushing, and creating pull requests.

# %% [markdown]
# ## 2. [Cookiecutter](https://cookiecutter-data-science.drivendata.org/)

# %% [markdown]
# Cookiecutter is a command-line utility that creates projects from cookiecutter templates. In the context of data science, using cookiecutter templates can significantly **streamline the project setup process, enhance reproducibility, and encourage best practices**. In this tutorial, we'll guide you through the process of cloning a data science cookiecutter template from [GitHub](https://github.com/drivendataorg/cookiecutter-data-science), exploring its structure, and highlighting the benefits it offers.

# %% [markdown]
# Step to Install the Cookiecutter Library with pip and start a project by executing below commands in terminal:
#
# ```bash
# # Install Cookiecutter using pip
# pip install cookiecutter-data-science
#
# # Start a new project
# ccds
# ```

# %% [markdown]
# The cookiecutter template uses variables enclosed in double curly braces (`{{ ... }}`) to customize the project structure. When you create a new project using the template, Cookiecutter prompts you to enter values for these variables. For example, `repo_name` might be the name of your project.

# %% [markdown]
# #### Project Organization
#
# ```
# ├── LICENSE            <- Open-source license if one is chosen
# ├── Makefile           <- Makefile with convenience commands like `make data` or `make train`
# ├── README.md          <- The top-level README for developers using this project.
# ├── data
# │   ├── external       <- Data from third party sources.
# │   ├── interim        <- Intermediate data that has been transformed.
# │   ├── processed      <- The final, canonical data sets for modeling.
# │   └── raw            <- The original, immutable data dump.
# │
# ├── docs               <- A default mkdocs project; see www.mkdocs.org for details
# │
# ├── models             <- Trained and serialized models, model predictions, or model summaries
# │
# ├── notebooks          <- Jupyter notebooks. Naming convention is a number (for ordering),
# │                         the creator's initials, and a short `-` delimited description, e.g.
# │                         `1.0-jqp-initial-data-exploration`.
# │
# ├── pyproject.toml     <- Project configuration file with package metadata for
# │                         {{ cookiecutter.module_name }} and configuration for tools like black
# │
# ├── references         <- Data dictionaries, manuals, and all other explanatory materials.
# │
# ├── reports            <- Generated analysis as HTML, PDF, LaTeX, etc.
# │   └── figures        <- Generated graphics and figures to be used in reporting
# │
# ├── requirements.txt   <- The requirements file for reproducing the analysis environment, e.g.
# │                         generated with `pip freeze > requirements.txt`
# │
# ├── setup.cfg          <- Configuration file for flake8
# │
# └── {{ cookiecutter.module_name }}   <- Source code for use in this project.
#     │
#     ├── __init__.py             <- Makes {{ cookiecutter.module_name }} a Python module
#     │
#     ├── config.py               <- Store useful variables and configuration
#     │
#     ├── dataset.py              <- Scripts to download or generate data
#     │
#     ├── features.py             <- Code to create features for modeling
#     │
#     ├── modeling
#     │   ├── __init__.py
#     │   ├── predict.py          <- Code to run model inference with trained models
#     │   └── train.py            <- Code to train models
#     │
#     └── plots.py                <- Code to create visualizations
# ```

# %% [markdown]
# ### Benefits of Using Cookiecutter Templates in Data Science
#
# #### Project Standardization
#
# Cookiecutter templates enforce a standardized project structure, making it easier for team members to understand and collaborate on projects. Consistent directory layouts enhance reproducibility and simplify project navigation.
#
# #### Reproducibility
#
# With a predefined project structure, it becomes straightforward to recreate the environment and rerun analyses. This contributes to the reproducibility of data science projects, a critical aspect in research and industry.
#
# #### Collaboration and Documentation
#
# The template encourages the inclusion of documentation at various levels, from code comments to dedicated `docs/` and `reports/` directories. This facilitates collaboration and ensures that knowledge is well-documented.
#
# #### Version Control
#
# Cookiecutter templates are typically designed to work seamlessly with version control systems like Git. This promotes good versioning practices, making it easy to track changes, collaborate, and roll back to previous project states if needed.
#
# #### Time Efficiency
#
# By eliminating the need to set up a project structure from scratch, cookiecutter templates save valuable time. This allows data scientists to focus on the core aspects of their work rather than dealing with project organization.

# %% [markdown]
# Incorporating cookiecutter templates into your data science workflow offers numerous advantages, from standardized project structures to enhanced reproducibility and collaboration. By following this tutorial and exploring the cookiecutter-datascience template, you can kickstart your data science projects with a solid foundation, setting the stage for success.

# %% [markdown]
# ## 3. [DVC](https://dvc.org/doc/install)

# %% [markdown]
# Data Version Control (DVC) is an open-source version control system designed specifically for handling machine learning projects. It allows you to efficiently manage and version your datasets, models, and experiments without duplicating large files. DVC seamlessly integrates with Git, enabling you to version control both code and data in a collaborative and reproducible manner.

# %% [markdown]
# ![](MLOPs_img/download1.png)

# %% [markdown]
# ### DVC Workflow with git and Cookiecutter Template

# %% [markdown]
# NOTE: pip install dvc[gs] for Google Storage Support and pip install dvc[s3] for AWS Storage Support.
#
# Run the Cookiecutter template, fill in your project details and move into the newly created directory.
#
# ```bash
# ccds
#
# cd your_project_name
# ```
# > NOTE: make sure `.env` and `.vscode/` are added to the `.gitignore` file.
#
# Create a new virtual environment and activate it. then install the dependencies from the `requirements.txt` file.
# ```bash
# conda create -n myenv python=3.9
# conda activate myenv
# ```
#
# Initialize Git
# ```bash
# git init
# ```
#
# Initialize DVC and It creates a **.dvcignore** file and **.dvc** internal directory that contains `cache`.
# ```bash
# dvc init
# ```
#
# Enable auto-staging of changes by DVC:
# ```bash
# dvc config core.autostage true
# ```
#
# **Auto Pull Data on Checkout with dvc install** : To avoid running dvc pull manually every time, This sets up Git hooks so that every time you git checkout a commit, DVC automatically runs dvc pull behind the scenes.
#
# ```bash
# dvc install
# ```
#
# Track the Data Folder generated by ccds with DVC. This adds the **raw** folder to your **.gitignore** file and creates `raw.dvc` file in data folder. rest of data and model folders will be tracked by **DVC Pipeline**, you just have to add `/dvclive/`, `/mlruns/`, `/models/`, `data/external/`, `data/interim/` and `data/processed/` to `.gitignore` file.
# ```bash
# dvc add data/raw
# dvc status
# ```
#
# Stage the CCDS scaffolding, the DVC config, and your new raw.dvc file and Commit Everything to Git all at once.
# ```bash
# git add .
# git commit -m "ccds template with git and dvc initialized"
# ```
#
# Push this repo to GitHub using VS Code Git extension.
#
# Now, DVC will track the `data` folder using `raw.dvc` file which is tracked by Git, while git won't touch the `data` folder. Now onwards, we can add the dataset to the data folder. Content of data folder will be added to the DVC cache

# %% [markdown]
# ### DVC Remote Setup

# %% [markdown]
# To setting up a Google Cloud Storage (GCS) bucket, installing and authenticating the Google Cloud CLI (`gcloud`), and connecting it to DVC pipeline. This will backup the non-frequent dataset from the cash to the remote server setup.
#
# ###### **Step 1: Create a GCS Bucket via the GCP Console**
# 1. **Navigate to Cloud Storage:** Open the left-hand navigation menu (hamburger icon) and go to **Cloud Storage > Buckets**.
# 2. **Create the Bucket:**
#     - Click the **+ Create** button.
#     - **Name:** Enter a globally unique name (e.g., `trip-duration-dvc-storages`).
#     - **Location Type:** Choose **Region** (cheaper, best for a specific geographic area) or **Multi-region** (higher availability).
#     - **Storage Class:** Select **Standard** (best for frequently accessed pipeline data).
#     - **Access Control:** Select **Uniform** to manage access at the bucket level.
# 3. Click **Create** at the bottom of the page.
#
# ###### **Step 2. Install gcloud CLI locally and Authenticate Your User Account**
# 1. **Windows (via Installer):** Download and run the [Google Cloud CLI Installer](https://dl.google.com/dl/cloudsdk/channels/rapid/GoogleCloudSDKInstaller.exe). Follow the setup wizard and leave the options checked to "Start Google Cloud SDK Shell" and "Run gcloud init".
# 2. Open your terminal or Google Cloud SDK Shell and initialize the CLI. This will open a browser window for you to log in.
# ```bash
# gcloud init
# ```
# - Follow the browser prompts to log in.
# - Select the GCP project you created/used in Step 1.
# - Select a default compute region when prompted.
# 3. While `gcloud init` logs *you* in, DVC needs programmatic access. You must generate Application Default Credentials (ADC) so DVC scripts can securely talk to your GCS bucket.
# ```bash
# gcloud auth application-default login
# ```
# - This will open *another* browser window. Log in and click "Allow." Your local machine is now fully authenticated for DVC.
#
# ###### **Step 3. Connect local DVC to GCS Bucket**
# ```bash
# # Install DVC's GCS dependencies
# pip install "dvc[gs]"
#
# # Add the GCS Remote as default
# dvc remote add -d myremote gs://trip-duration-dvc-storages/dvcstore
#
# # Commit the remote configuration to Git and push changes to GitHub
# git add .dvc/config
# git commit -m "Add DVC remote configuration"
# git push origin master
#
# # To push and pull your Data, artifacts, and Models to Remote Storage. DVC will automatically detect the credentials.
# dvc push
# dvc pull
# ```

# %% [markdown]
# ### How to Update DVC and Git When Data or Code Changes ?

# %% [markdown]
# This is the **standard process** to follow when you make changes to:
#
# - Just the **data**,
# - Just the **code**, or
# - **Both** data and code.
#
# #### 1️⃣ Check if DVC-Tracked Data Has Changed
# ```bash
# dvc status
# ```
# - If it shows changes in data, you need to create a new version of it in DVC.
#
# #### 2️⃣ Commit the New Version of Data to DVC
# ```bash
# dvc commit
# ```
# - This finalizes the new data version.
# - It will update `.dvc` files (like `raw.dvc`) and may change `.gitignore`.
#
# #### 3️⃣ Check Git Status
# ```bash
# git status
# ```
# - If only **data changed**, you’ll see:
#   - `raw.dvc`
#   - `.gitignore`
# - If **code also changed**, you’ll see other files too (e.g., `test.py`, `src/app.py`, etc.).
#
# #### 4️⃣ Stage All the Changes, Commit to Git and Push to GitHub
# ```bash
# git add .
# git commit -m "Updated data and/or code"
# git push
# ```

# %% [markdown]
# ### DVC Versioning with Git

# %% [markdown]
# #### View Git Log (with DVC Tracking IDs)
# ```bash
# git log
# ```
# - Shows commit history, including DVC-tracked changes.
# - Press `q` to **exit** the log view.
#
# #### Checkout a Previous Commit (Without Deleting Later Commits)
# ```bash
# git checkout <commit-id>
# ```
# - This moves `HEAD` to that commit and updates `raw.dvc` to that version.
# - `git checkout main` to return to the main branch.
#
# #### How DVC Handles Data Versions ?
#
# - Every time you make changes and `dvc commit` then `git commit`, a new version of `raw.dvc` is created and committed to Git.
# - If you have **100s of versions**, you'll have 100 versions of `raw.dvc` in Git history — but only **one physical file** in your project at a time.
# - Meanwhile, the actual data blobs are all stored (and versioned) in `.dvc/cache/` or your remote (like `tmp/`, `AWS S3`), **not in Git**.
#
# #### Restore the Correct Version of Data
#
# ```bash
# dvc pull
# ```
# - This will update the `data/` folder to match the currently checked-out version of `raw.dvc`.

# %% [markdown]
# ### Create and version ML pipeline using DVC Pipeline with mlflow Experimentation Tracking

# %% [markdown]
# ![ML-Pipeline.jpeg](MLOps_img/ML-Pipeline.jpeg)

# %% [markdown]
# ![ML-Pipeline.jpeg](MLOps_img/download3.png)

# %% [markdown]
# **ML End-to-End (e2e) Pipeline** can be broken down into three parts:
# 1. **Data Pipeline** : (Data Collection to Feature Engineering)
# 2. **Experimentation Pipeline** or **Experimentation DAG (Directed Acyclic Graph)** : (Model Selection to Model Validation)
# 3. **Deployment & Monitoring Pipeline** : (Model Deployment to Monitoring & Updating)

# %% [markdown]
# Experimentation tracking is an outcome of pipeline i.e. we track everything related of a running DVC pipeline. You can track your data and pipeline with DVC while you can log the experimentation details and artefacts in `MLflow` or DVC(`dvclive`) or `ZenML` or `W&B` or `Kubeflow` or `Airflow` or `TensorBoard` or `Guild`. MLFlow is a better choice and is used everywhere in the industry either in a self-managed setup or via DataBricks.
#
# - `params.yaml` (**The Control Panel**): This is where you store your hyperparameters and configuration variables (e.g., learning rate, number of epochs, random seed). While it's just a standard YAML file, dvc.yaml specifically points to it. The magic here is that DVC tracks individual keys inside this file. If you change the learning_rate parameter, DVC knows to re-run only the training stage, not the data preparation stage.
# - `dvc.yaml` (**The Architect**): This is the blueprint of your machine learning pipeline. You write this file manually (or generate it via dvc stage add). It defines the different stages of your pipeline (e.g., prepare, train, evaluate), the commands to run them, the inputs they depend on (deps), and the outputs they produce (outs, metrics, plots). It is like shell script but easy to write.
# - `dvc.lock` (**The Snapshot**): You do not write or edit this file. DVC automatically generates it when you run your pipeline (dvc repro). It captures the exact state of your pipeline at that moment by recording the MD5 hashes of all dependencies, parameters, and outputs. If dvc.yaml is the blueprint, dvc.lock is the photograph of the finished building, ensuring 100% reproducibility.
# - `*.dvc files` (**e.g., data/raw.dvc**): When you track a large file using dvc add dataset.csv, DVC generates a tiny text file named dataset.csv.dvc. This file contains the cryptographic hash of your dataset. You commit this .dvc file to Git, while the actual heavy CSV goes into DVC's cache.
# - `.dvc/config`: This is the DVC configuration file. Most importantly, it stores the information about your remote storage (like an AWS S3 bucket, Google Cloud Storage, or a local network drive) where your actual heavy data is pushed to and pulled from.
# - `src/dataset.py`: Reads the raw dataset and splits it into `train.csv` and `test.csv` under `data/processed/`.
# - `src/train.py`: Trains a machine learning model using the training dataset. It evaluates on the test set and saves the model to `models/model.joblib`.
# - `src/plots.py`: It loads the saved model and test data and generates performance visualization (confusion matrix, ROC curve, etc.).
#
# To create the DVC pipeline, we are required to create and write below files:
# 1. `params.yaml`
# 2. `dvc.yaml`
# 3. `src/dataset.py`
# 4. `src/train.py`
# 5. `src/plots.py`
#
# ```bash
# # Example: Create a DVC file for a pre-processing step
# dvc run - d data/raw/data.csv - o data/processed/train.csv python code/dataset.py
#
# # Example: Train a machine learning model
# dvc run - d data/processed/train.csv - o models/model.pkl python code/train.py
# ```

# %% [markdown]
# ### Track changes and reproduce experiments

# %% [markdown]
# ```bash
# # During training, logs will be saved automatically in dvclive/ folder
# pip install dvclive
# ```
#
# ```bash
# # During training, logs will be saved automatically in mlruns/ folder
# # For Data Scientists, during training
# pip install mlflow[extras]
#
# # For MLOps, durning deployment
# pip install mlflow[server]
# ```
#
# ```bash
# # During training, logs will be saved automatically in server
# import mlflow
# mlflow.set_tracking_uri("sqlite:///mlflow.db")
# ```
#
# ```bash
# # This will start the MLflow web interface
# mlflow server
# ```
#
#
# ```bash
# # Check the status of your project
# dvc status
# ```
#
#
# ```bash
# # To run the DVC Pipeline
# dvc repro
#
# # Reproduce the pipeline at a specific commit
# dvc repro -s <commit_hash>
# ```
# - **When Data Changed** (e.g., data/raw.csv) : It identifies which stages depend on the changed data and re-runs them. It overwrites or creates your `dvc.lock` file with the new data hashes and output hashes. You are expected to manually run `git add dvc.lock` and `git commit`. This represents a permanent, official "step forward" in your project's history.
# - **When params.yaml Changed** (like changing learning rates or epochs) : You must manually open `params.yaml`, change the value, save the file, and run `dvc repro`. DVC re-runs the stages dependent on that parameter and updates `dvc.lock`. Again, you must manually commit these changes to Git. If you want to test 5 different learning rates, you have to do this 5 times, creating 5 standard Git commits (or messy branches).
#
#
# ```bash
# # To run experiments
# dvc exp run
# ```
# - **When Data Changed** (e.g., data/raw.csv) : It also re-runs the dependent stages. Instead of forcing you to make a standard Git commit, it automatically creates a hidden, temporary Git reference (an "experiment," like exp-a1b2c3). You can view this run using dvc exp show. If the new data yielded bad results, you can simply ignore or delete the experiment without having polluted your main Git branch. If it's good, you can apply it (`dvc exp apply`).
# - **When params.yaml Changed** (like changing learning rates or epochs) : You can change the file manually and run it, OR you can change parameters on the fly without ever opening the file by using the --set-param (-S) flag: `dvc exp run -S train.epochs=50`. DVC automatically queues and runs the pipeline with the new parameter, tracks the metrics, and logs it as a distinct experiment. You can easily compare all your different parameter tweaks side-by-side by running `dvc exp show`. It keeps your workspace clean while logging every variation.

# %% [markdown]
# If we get to the previous version then to verify it is the right version,
# 1. we can match the experiment output of the version to the records of the version we have in the Experiments and the both will be same.
# 2. go to the visualize.py and add print statement to print the output metrics and match with the records of the version we have in the Experiments

# %% [markdown]
# - take name of output from dvc.yaml only
# - params in dvc.yaml enables dvc repro to track the parameters and their changes.
# - in dvc.yaml, `name of the stage` must be equal to file name just any name but preferred same to correlate and order of `deps` don't matter.
# - notebook is for eda and visualization purpose. once code is ready then paste the code in src files.
# - **stages** in DVC and DVC Pipeline or dvc.yaml file means pipeline.
